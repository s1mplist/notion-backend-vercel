# %%
# Add the project root to Python path so we can import our modules
import sys
import os

sys.path.append(os.path.abspath(".."))

# Verify we can import our module
try:
    from src.models.notion.webhook import BaseWebHook

    print("✅ Successfully imported BaseWebHook from src.models.notion.webhook")
except ImportError as e:
    print(f"❌ Failed to import module: {e}")
    print("Current Python path:")
    for path in sys.path:
        print(f"  - {path}")

# %%
from dotenv import load_dotenv

load_dotenv("../environments/dev/.env")

# %%
import os
from notion_client import Client


with Client(auth=os.environ["NOTION_TOKEN"]) as notion:
    print(notion.users.list())

# %%
from src.models.notion.webhook import BaseWebHook

req_sample = {
    "id": "c00e2ea7-032a-4e20-ae05-d69028a09ae9",
    "timestamp": "2024-12-05T23:51:27.295Z",
    "workspace_id": "13950b26-c203-4f3b-b97d-93ec06319565",
    "workspace_name": "Quantify Labs",  # This field is not in the model but will be ignored
    "subscription_id": "29d75c0d-5546-4414-8459-7b7a92f1fc4b",
    "integration_id": "0ef2e755-4912-8096-91c1-00376a88a5ca",
    "type": "database.deleted",
    "authors": [{"id": "c7c11cca-1d73-471d-9b6e-bdef51470190", "type": "person"}],
    "accessible_by": [
        {"id": "556a1abf-4f08-40c6-878a-75890d2a88ba", "type": "person"},
        {"id": "1edc05f6-2702-81b5-8408-00279347f034", "type": "bot"},
    ],
    "attempt_number": 1,
    "entity": {"id": "153104cd-477e-80eb-ae76-e1c2a32c7b35", "type": "database"},
    "data": {"parent": {"id": "0ef104cd-477e-80e1-8571-cfd10e92339a", "type": "page"}},
}

# Create the webhook model instance
req_sample_model = BaseWebHook(**req_sample)

# Display the created model
print("Webhook model created successfully!")
print(f"Model ID: {req_sample_model.id}")
print(f"Model Type: {req_sample_model.type}")
print(f"Model Timestamp: {req_sample_model.timestamp}")
print(f"Model Workspace ID: {req_sample_model.workspace_id}")
print(f"Number of Authors: {len(req_sample_model.authors)}")
print(f"Number of Accessible By: {len(req_sample_model.accessible_by)}")

# %%
html = """
<!DOCTYPE html>
<html lang="pt-BR">

<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Relatório Técnico - </title>
    <style>
/* Variáveis CSS */
:root {
    --primary-color: #0f4c45;
    --secondary-color: #0fca62;
    --text-color: #333;
    --border-color: #e0e0e0;
    --background-light: #f5f5f5;
    --spacing-unit: 1rem;
}

/* Reset e estilos base */
* {
    margin: 0;
    padding: 0;
    box-sizing: border-box;
}

body {
    font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, sans-serif;
    line-height: 1.5;
    color: var(--text-color);
    background-color: white;
    padding: var(--spacing-unit);
    font-size: 14px;
}

/* Configuração de página para PDF - tamanho aumentado */
@page {
    size: 210mm 350mm;
    margin: 1cm;
}

/* Cabeçalho */
.header {
    display: flex;
    flex-direction: column;
    align-items: center;
    margin-bottom: 2rem;
    width: 100%;
}

.header img {
    max-width: 100%;
    width: 100%;
    margin-bottom: var(--spacing-unit);
}

/* Grid de informações */
.info-grid {
    display: grid;
    grid-template-columns: repeat(3, 1fr);
    gap: var(--spacing-unit);
    margin-bottom: 2rem;
    width: 100%;
    max-width: 100%;
}

.info-item {
    background: var(--background-light);
    padding: var(--spacing-unit);
    border-radius: 8px;
}

.info-label {
    font-weight: 600;
    color: var(--primary-color);
    font-size: 0.8em;
    text-transform: uppercase;
    letter-spacing: 0.5px;
    margin-bottom: 2px;
}

.info-value {
    color: var(--secondary-color);
    font-weight: 500;
    font-size: 0.95em;
}

/* Seções */
.section {
    margin-bottom: 2rem;
}

.section-title {
    color: var(--primary-color);
    font-size: 1.5em;
    font-weight: 600;
    margin-bottom: var(--spacing-unit);
    padding-bottom: 0.5rem;
    border-bottom: 2px solid var(--primary-color);
}

/* Talhões - peça única indivisível */
.talhao {
    background: white;
    border-radius: 8px;
    padding: 0.6rem;
    margin-bottom: 0;
    border: 1px solid var(--border-color);
    page-break-inside: avoid !important;
    break-inside: avoid !important;
    page-break-before: always;
}

.talhao:first-of-type {
    page-break-before: auto;
}

.talhao-info {
    display: grid;
    grid-template-columns: repeat(3, 1fr);
    gap: 0.5rem;
    background: var(--background-light);
    padding: 0.5rem;
    border-radius: 6px;
    margin-bottom: 0.5rem;
}

/* Galeria de imagens */
.images-and-assessment-group {
    page-break-inside: avoid !important;
    break-inside: avoid !important;
}

.image-gallery {
    display: grid;
    grid-template-columns: repeat(2, 1fr);
    gap: 0.5rem;
    margin: 0.5rem 0;
}

.gallery-image-wrapper {
    position: relative;
    overflow: hidden;
}

.gallery-image {
    width: 100%;
    height: 180px;
    object-fit: cover;
    border-radius: 6px;
    border: 1px solid var(--border-color);
}

/* Avaliação */
.avaliacao {
    background: var(--background-light);
    padding: 0.5rem;
    border-radius: 6px;
    margin-top: 0.5rem;
}

/* Cronograma */
.schedule {
    background: white;
    border-radius: 8px;
    border: 1px solid var(--border-color);
    overflow: hidden;
    margin: var(--spacing-unit) 0;
}

.schedule-item {
    display: grid;
    grid-template-columns: auto 1fr;
    gap: var(--spacing-unit);
    padding: 0.5rem 1rem;
    border-bottom: 1px solid var(--border-color);
}

.schedule-date {
    font-weight: 500;
    color: var(--primary-color);
}

/* Sumário Executivo */
.executive-summary {
    page-break-inside: avoid;
    break-inside: avoid;
}

.summary-card {
    background: white;
    border-radius: 8px;
    border: 2px solid var(--primary-color);
    padding: 1rem;
    margin-bottom: 1rem;
}

.summary-item {
    display: flex;
    gap: 1rem;
    margin-bottom: 1.2rem;
    padding-bottom: 1.2rem;
    border-bottom: 1px solid var(--border-color);
}

.summary-item:last-child {
    margin-bottom: 0;
    padding-bottom: 0;
    border-bottom: none;
}

.summary-icon {
    font-size: 2em;
    line-height: 1;
    flex-shrink: 0;
}

.summary-content {
    flex: 1;
}

.summary-label {
    font-weight: 600;
    color: var(--primary-color);
    font-size: 1.1em;
    margin-bottom: 0.3rem;
}

.summary-text {
    color: var(--text-color);
    line-height: 1.5;
    margin-bottom: 0.5rem;
}

.summary-schedule {
    margin-top: 0.5rem;
    padding-left: 1rem;
}

.summary-schedule ol,
.summary-schedule ul {
    margin: 0.5rem 0;
    padding-left: 1.5rem;
}

.summary-schedule li {
    margin-bottom: 0.3rem;
    line-height: 1.5;
}

/* Footer */
.footer {
    text-align: center;
    margin-top: 2rem;
    padding-top: 1rem;
    border-top: 1px solid var(--border-color);
    color: var(--text-color);
}

.footer img {
    max-width: 150px;
    margin-bottom: var(--spacing-unit);
}

/* Utilitários */
.text-center { text-align: center; }
.mb-1 { margin-bottom: 0.4rem; }
.mb-2 { margin-bottom: 2rem; }
.mt-1 { margin-top: 0.4rem; }
.mt-2 { margin-top: 2rem; }

/* Cards */
.card {
    background: white;
    border-radius: 6px;
    border: 1px solid var(--border-color);
    padding: 0.5rem;
    margin-bottom: 0.5rem;
}

.badge {
    display: inline-block;
    padding: 4px 8px;
    border-radius: 4px;
    font-size: 0.8em;
    font-weight: 500;
}

.badge-primary {
    background: var(--primary-color);
    color: white;
}

.badge-secondary {
    background: var(--secondary-color);
    color: white;
}

/* Print */
@media print {
    .talhao {
        page-break-before: always !important;
        page-break-inside: avoid !important;
        break-inside: avoid !important;
    }
    
    .talhao:first-of-type {
        page-break-before: auto !important;
    }
}

</style>
    <meta name="color-scheme" content="light">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <style>
        /* Pequenos ajustes específicos para WeasyPrint, sem alterar o styles.css original */
        .header img { max-width: 100%; height: auto; }
    </style>
    </head>

<body>
    <!-- Cabeçalho -->
    <header class="header">
        <img src="./images/img_visita_tecnica.jpeg" alt="Banner" loading="eager" decoding="async">
        <div class="info-grid">
            <div class="info-item">
                <div class="info-label">Consultor Técnico</div>
                <div class="info-value"></div>
            </div>
            <div class="info-item">
                <div class="info-label">Fazenda</div>
                <div class="info-value"></div>
            </div>
            <div class="info-item">
                <div class="info-label">Mês</div>
                <div class="info-value">October 2025</div>
            </div>
            <div class="info-item">
                <div class="info-label">Proprietário</div>
                <div class="info-value"></div>
            </div>
            <div class="info-item">
                <div class="info-label">Cidade</div>
                <div class="info-value"></div>
            </div>
            <div class="info-item">
                <div class="info-label">Safra</div>
                <div class="info-value">2025/2026</div>
            </div>
        </div>
    </header>

    <!-- Sumário Executivo -->
    <section class="section executive-summary">
        <div class="summary-card">
            <div class="summary-item">
                <span class="summary-icon">📋</span>
                <div class="summary-content">
                    <div class="summary-label">Informações Gerais</div>
                    <div class="summary-text">Visita realizada para avaliação das áreas já plantadas, programação de manejos e acompanhamento de plantio.
A previsão de término do plantio de soja é na próxima semana. O rendimento está muito bom.
Após finalizar o Setor 1, iremos para o Setor 2, Setor 6, Entorno dos Pivôs e Setor 3.</div>
                </div>
            </div>
            
            <div class="summary-item">
                <span class="summary-icon">📅</span>
                <div class="summary-content">
                    <div class="summary-label">Próxima visita técnica:</div>
                    <div class="summary-text">26/10/2025</div>
                </div>
            </div>
            
            <div class="summary-item">
                <span class="summary-icon">⏱️</span>
                <div class="summary-content">
                    <div class="summary-label">Cronograma de Operações</div>
                    <div class="summary-text">(22/10/2025 à 26/10/2025)</div>
                    <div class="summary-schedule"></div>
                </div>
            </div>
        </div>
    </section>

    <!-- Talhões -->
    
        
<div class="talhao">
    <div class="talhao-info">
        <div>
            <div class="info-label">Talhão</div>
            <div class="info-value">talhao_1</div>
        </div>
        <div>
            <div class="info-label">Área</div>
            <div class="info-value">0.0ha</div>
        </div>
        <div>
            <div class="info-label">Estádio Fenológico</div>
%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw2Mzc0MjMxODM4MDUiDJwv0WZOFnwugqef6SrcA3%2BzbMZbhU%2B2L6XHXdEY3ZJI8SYBbRZXKyp%2BsAisV%2B7Z318b6%2Bw1euO4cxt5rTgf4mClKNpRYbkkzVNbcGbiFJ%2BEnJPGhauLX%2FP51LDNxwZPd%2F5Jeb8dXPLte3BN4Lp4gu7TcwVA0LEWDWXQTZ7ihDP95tm7Xi3ojG7EYDT6JIMSUbmnLeOYfW2%2FYh6JPyU%2B3%2FILfXC6E5MJSerLmmNAEUg%2FpUY51OCE%2BzLSKxImgW2jibsVt2qfqUyaPrTGSUaMMSYzDq57CWkuYMpMhtaLYDiRPMBilZFU%2FrsK6FxRaU%2BlbjwePm0LW2duQF596FPd7IfktN1gUfvma2iGJ%2F5WzhKQQjilHVSD1HUdXE11Tv0NdN191JAaEWElRBvNcC6%2FWCeY%2FPUCk5sJ6HYdDSwjHGastI0p0julvuvhc19i1zFt0AND0FSq3VvXBIHonhaF%2Bu%2Bq4gcipyBn2YFQUcoSc%2B3m9zLNU9zYNCE5RJCRQb4DF9h2d0MGM%2B0Oj%2FOLlcim2ah1uN8nJBCRX%2BLth4pvIOkOx0OuPIB3e078A5mNe1JbejUYlPAh1uUiLkLiDkYExoxroriFmOCoTUDqMS8UbzFvJf4tMfWiXxgZA45QkBsZ5I3JqP6GHmqwwIlAML34%2BscGOqUBx9H%2BNu6jAsVJhrgc6KBJNpC%2FKbgEqK91wZf57z40srzdZTMeYHA6lYPzbtg89zMPFbveMHsOKrk3ZWDw5uuMin1RQ5fVJDroPph6oOEn6JRDCm3wDXmPnt5WfZqGAarifWhfL6f2tLn6%2FLyH%2FOkTfVz%2BAeTtwyea%2BiCrbvThmpnRLn2poIabnDCtrbdsmpj%2F0dFbS2PcHLLoyNJUjpQ9JOVQygNb&X-Amz-Signature=9e8763e6ca428546977fb0fe1050e0f27ed398ca15116d4e1f87a51ecc176d48&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" alt="" class="gallery-image" loading="lazy" decoding="async" style="max-width:100%;height:auto;display:block;" onerror="this.style.display='none'">
            </div>
            
        </div>

        <div class="avaliacao">
            <div class="info-label mb-1">Avaliação</div>
            <div>Lavoura em início de germinação. Acelerar irrigação para termos uniformidade na germinação.</div>
        </div>
    </div>
</div>
    
        
<div class="talhao">
    <div class="talhao-info">
        <div>
            <div class="info-label">Talhão</div>
            <div class="info-value">talhao_2</div>
        </div>
        <div>
            <div class="info-label">Área</div>
            <div class="info-value">0.0ha</div>
        </div>
        <div>
            <div class="info-label">Estádio Fenológico</div>
            <div class="info-value badge badge-secondary">V1</div>
        </div>
    </div>

    <div class="card mb-1">
        <div class="info-label">Cultura e Variedade</div>
        <div class="info-value mt-1">Pivô 2 - </div>
    </div>

    <div class="images-and-assessment-group">
        <div class="image-gallery">
            
            <div class="gallery-image-wrapper">
                <img src="https://prod-files-secure.s3.us-west-2.amazonaws.com/2362cd84-cc08-450c-bf8c-ed1742192c46/534f95b0-24f2-40e3-85f3-37b7c444bf20/IMG_9377.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIAZI2LB466VT554GDJ%2F20251027%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20251027T012600Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEOH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJHMEUCIDa7jHwvJxliO7ORMi9jARWqiWINKczHoW2bj346BxSYAiEAntaEdMyggyhZoemo3xYLqfycd2X41qdqgHZ0Dj9waRkqiAQImv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw
N8nJBCRX%2BLth4pvIOkOx0OuPIB3e078A5mNe1JbejUYlPAh1uUiLkLiDkYExoxroriFmOCoTUDqMS8UbzFvJf4tMfWiXxgZA45QkBsZ5I3JqP6GHmqwwIlAML34%2BscGOqUBx9H%2BNu6jAsVJhrgc6KBJNpC%2FKbgEqK91wZf57z40srzdZTMeYHA6lYPzbtg89zMPFbveMHsOKrk3ZWDw5uuMin1RQ5fVJDroPph6oOEn6JRDCm3wDXmPnt5WfZqGAarifWhfL6f2tLn6%2FLyH%2FOkTfVz%2BAeTtwyea%2BiCrbvThmpnRLn2poIabnDCtrbdsmpj%2F0dFbS2PcHLLoyNJUjpQ9JOVQygNb&X-Amz-Signature=486fcb51cbf1349943007911bffd684a8eb8314a8aa03659848e35cc7c7e9a46&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" alt="" class="gallery-image" loading="lazy" decoding="async" style="max-width:100%;height:auto;display:block;" onerror="this.style.display='none'">
            </div>
            
        </div>

        <div class="avaliacao">
            <div class="info-label mb-1">Avaliação</div>
            <div>Lavoura vem apresentando ótimo arranque inicial, com excelente enraizamento e início de nodulação de qualidade. Apresenta pequena pressão de vaquinha e início de rebrote de daninhas, em baixa pressão.</div>
        </div>
    </div>
</div>
    
        
<div class="talhao">
    <div class="talhao-info">
        <div>
            <div class="info-label">Talhão</div>
            <div class="info-value">talhao_3</div>
        </div>
        <div>
            <div class="info-label">Área</div>
            <div class="info-value">0.0ha</div>
        </div>
        <div>
            <div class="info-label">Estádio Fenológico</div>
            <div class="info-value badge badge-secondary">V1/V2</div>
        </div>
    </div>

    <div class="card mb-1">
        <div class="info-label">Cultura e Variedade</div>
        <div class="info-value mt-1">Pivô 3 - </div>
    </div>

    <div class="images-and-assessment-group">
        <div class="image-gallery">
            
            <div class="gallery-image-wrapper">
                <img src="https://prod-files-secure.s3.us-west-2.amazonaws.com/2362cd84-cc08-450c-bf8c-ed1742192c46/508c05d5-34f3-42d1-9e74-d55bbe55f1f0/IMG_9380.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIAZI2LB466VT554GDJ%2F20251027%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20251027T012600Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEOH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJHMEUCIDa7jHwvJxliO7ORMi9jARWqiWINKczHoW2bj346BxSYAiEAntaEdMyggyhZoemo3xYLqfycd2X41qdqgHZ0Dj9waRkqiAQImv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw2Mzc0MjMxODM4MDUiDJwv0WZOFnwugqef6SrcA3%2BzbMZbhU%2B2L6XHXdEY3ZJI8SYBbRZXKyp%2BsAisV%2B7Z318b6%2Bw1euO4cxt5rTgf4mClKNpRYbkkzVNbcGbiFJ%2BEnJPGhauLX%2FP51LDNxwZPd%2F5Jeb8dXPLte3BN4Lp4gu7TcwVA0LEWDWXQTZ7ihDP95tm7Xi3ojG7EYDT6JIMSUbmnLeOYfW2%2FYh6JPyU%2B3%2FILfXC6E5MJSerLmmNAEUg%2FpUY51OCE%2BzLSKxImgW2jibsVt2qfqUyaPrTGSUaMMSYzDq57CWkuYMpMhtaLYDiRPMBilZFU%2FrsK6FxRaU%2BlbjwePm0LW2duQF596FPd7IfktN1gUfvma2iGJ%2F5WzhKQQjilHVSD1HUdXE11Tv0NdN191JAaEWElR
X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" alt="" class="gallery-image" loading="lazy" decoding="async" style="max-width:100%;height:auto;display:block;" onerror="this.style.display='none'">
            </div>
            
        </div>

        <div class="avaliacao">
            <div class="info-label mb-1">Avaliação</div>
            <div>Lavoura vem apresentando ótimo arranque inicial, com excelente enraizamento e início de nodulação de qualidade. Apresenta pequena pressão de vaquinha e início de rebrote de daninhas, em baixa pressão.</div>
        </div>
    </div>
</div>
    
        
<div class="talhao">
    <div class="talhao-info">
        <div>
            <div class="info-label">Talhão</div>
            <div class="info-value">talhao_4</div>
        </div>
        <div>
            <div class="info-label">Área</div>
            <div class="info-value">0.0ha</div>
        </div>
        <div>
            <div class="info-label">Estádio Fenológico</div>
            <div class="info-value badge badge-secondary">VE</div>
        </div>
    </div>

    <div class="card mb-1">
        <div class="info-label">Cultura e Variedade</div>
        <div class="info-value mt-1">Setor 5 - </div>
    </div>

    <div class="images-and-assessment-group">
        <div class="image-gallery">
            
            <div class="gallery-image-wrapper">
                <img src="https://prod-files-secure.s3.us-west-2.amazonaws.com/2362cd84-cc08-450c-bf8c-ed1742192c46/958c7756-4fec-4ee5-a7c0-103d795a9134/IMG_9386.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIAZI2LB466VT554GDJ%2F20251027%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20251027T012600Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEOH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJHMEUCIDa7jHwvJxliO7ORMi9jARWqiWINKczHoW2bj346BxSYAiEAntaEdMyggyhZoemo3xYLqfycd2X41qdqgHZ0Dj9waRkqiAQImv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw2Mzc0MjMxODM4MDUiDJwv0WZOFnwugqef6SrcA3%2BzbMZbhU%2B2L6XHXdEY3ZJI8SYBbRZXKyp%2BsAisV%2B7Z318b6%2Bw1euO4cxt5rTgf4mClKNpRYbkkzVNbcGbiFJ%2BEnJPGhauLX%2FP51LDNxwZPd%2F5Jeb8dXPLte3BN4Lp4gu7TcwVA0LEWDWXQTZ7ihDP95tm7Xi3ojG7EYDT6JIMSUbmnLeOYfW2%2FYh6JPyU%2B3%2FILfXC6E5MJSerLmmNAEUg%2FpUY51OCE%2BzLSKxImgW2jibsVt2qfqUyaPrTGSUaMMSYzDq57CWkuYMpMhtaLYDiRPMBilZFU%2FrsK6FxRaU%2BlbjwePm0LW2duQF596FPd7IfktN1gUfvma2iGJ%2F5WzhKQQjilHVSD1HUdXE11Tv0NdN191JAaEWElRBvNcC6%2FWCeY%2FPUCk5sJ6HYdDSwjHGastI0p0julvuvhc19i1zFt0AND0FSq3VvXBIHonhaF%2Bu%2Bq4gcipyBn2YFQUcoSc%2B3m9zLNU9zYNCE5RJCRQb4DF9h2d0MGM%2B0Oj%2FOLlcim2ah1uN8nJBCRX%2BLth4pvIOkOx0OuPIB3e078A5mNe1JbejUYlPAh1uUiLkLiDkYExoxroriFmOCoTUDqMS8UbzFvJf4tMfWiXxgZA45QkBsZ5I3JqP6GHmqwwIlAML34%2BscGOqUBx9H%2BNu6jAsVJhrgc6KBJNpC%2FKbgEqK91wZf57z40srzdZTMeYHA6lYPzbtg89zMPFbveMHsOKrk3ZWDw5uuMin1RQ5fVJDroPph6oOEn6JRDCm3wDXmPnt5WfZqGAarifWhfL6f2tLn6%2FLyH%2FOkTfVz%2BAeTtwyea%2BiCrbvThmpnRLn2poIabnDCtrbdsmpj%2F0dFbS2PcHLLoyNJUjpQ9JOVQygNb&X-Amz-Signature=0403fbf4389e27e2afe2153c8a502b0f09080ec49dff2bf23ec6a54b19d2183a&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetOb
jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIAZI2LB466VT554GDJ%2F20251027%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20251027T012600Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEOH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJHMEUCIDa7jHwvJxliO7ORMi9jARWqiWINKczHoW2bj346BxSYAiEAntaEdMyggyhZoemo3xYLqfycd2X41qdqgHZ0Dj9waRkqiAQImv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw2Mzc0MjMxODM4MDUiDJwv0WZOFnwugqef6SrcA3%2BzbMZbhU%2B2L6XHXdEY3ZJI8SYBbRZXKyp%2BsAisV%2B7Z318b6%2Bw1euO4cxt5rTgf4mClKNpRYbkkzVNbcGbiFJ%2BEnJPGhauLX%2FP51LDNxwZPd%2F5Jeb8dXPLte3BN4Lp4gu7TcwVA0LEWDWXQTZ7ihDP95tm7Xi3ojG7EYDT6JIMSUbmnLeOYfW2%2FYh6JPyU%2B3%2FILfXC6E5MJSerLmmNAEUg%2FpUY51OCE%2BzLSKxImgW2jibsVt2qfqUyaPrTGSUaMMSYzDq57CWkuYMpMhtaLYDiRPMBilZFU%2FrsK6FxRaU%2BlbjwePm0LW2duQF596FPd7IfktN1gUfvma2iGJ%2F5WzhKQQjilHVSD1HUdXE11Tv0NdN191JAaEWElRBvNcC6%2FWCeY%2FPUCk5sJ6HYdDSwjHGastI0p0julvuvhc19i1zFt0AND0FSq3VvXBIHonhaF%2Bu%2Bq4gcipyBn2YFQUcoSc%2B3m9zLNU9zYNCE5RJCRQb4DF9h2d0MGM%2B0Oj%2FOLlcim2ah1uN8nJBCRX%2BLth4pvIOkOx0OuPIB3e078A5mNe1JbejUYlPAh1uUiLkLiDkYExoxroriFmOCoTUDqMS8UbzFvJf4tMfWiXxgZA45QkBsZ5I3JqP6GHmqwwIlAML34%2BscGOqUBx9H%2BNu6jAsVJhrgc6KBJNpC%2FKbgEqK91wZf57z40srzdZTMeYHA6lYPzbtg89zMPFbveMHsOKrk3ZWDw5uuMin1RQ5fVJDroPph6oOEn6JRDCm3wDXmPnt5WfZqGAarifWhfL6f2tLn6%2FLyH%2FOkTfVz%2BAeTtwyea%2BiCrbvThmpnRLn2poIabnDCtrbdsmpj%2F0dFbS2PcHLLoyNJUjpQ9JOVQygNb&X-Amz-Signature=d3ed50461877b06fb67999a5b930a0b90374d19862685b1d3538e62efefa0382&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" alt="" class="gallery-image" loading="lazy" decoding="async" style="max-width:100%;height:auto;display:block;" onerror="this.style.display='none'">
            </div>
            
        </div>

        <div class="avaliacao">
            <div class="info-label mb-1">Avaliação</div>
            <div>Area em início de germinação. Até o momento com boa qualidade. Avaliação na próxima visita.</div>
        </div>
    </div>
</div>
    
        
<div class="talhao">
    <div class="talhao-info">
        <div>
            <div class="info-label">Talhão</div>
            <div class="info-value">talhao_5</div>
        </div>
        <div>
            <div class="info-label">Área</div>
            <div class="info-value">0.0ha</div>
        </div>
        <div>
            <div class="info-label">Estádio Fenológico</div>
            <div class="info-value badge badge-secondary">-</div>
        </div>
    </div>

    <div class="card mb-1">
        <div class="info-label">Cultura e Variedade</div>
        <div class="info-value mt-1">Entorno do Pivôs - </div>
    </div>

    <div class="images-and-assessment-group">
        <div class="image-gallery">
            
            <div class="gallery-image-wrapper">
                <img src="https://prod-files-secure.s3.us-west-2.amazonaws.com/2362cd84-cc08-450c-bf8c-ed1742192c46/9b6cf2aa-0b94-4ccb-ba34-b5bea2b92592/IMG_9382.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential
%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJHMEUCIDa7jHwvJxliO7ORMi9jARWqiWINKczHoW2bj346BxSYAiEAntaEdMyggyhZoemo3xYLqfycd2X41qdqgHZ0Dj9waRkqiAQImv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw2Mzc0MjMxODM4MDUiDJwv0WZOFnwugqef6SrcA3%2BzbMZbhU%2B2L6XHXdEY3ZJI8SYBbRZXKyp%2BsAisV%2B7Z318b6%2Bw1euO4cxt5rTgf4mClKNpRYbkkzVNbcGbiFJ%2BEnJPGhauLX%2FP51LDNxwZPd%2F5Jeb8dXPLte3BN4Lp4gu7TcwVA0LEWDWXQTZ7ihDP95tm7Xi3ojG7EYDT6JIMSUbmnLeOYfW2%2FYh6JPyU%2B3%2FILfXC6E5MJSerLmmNAEUg%2FpUY51OCE%2BzLSKxImgW2jibsVt2qfqUyaPrTGSUaMMSYzDq57CWkuYMpMhtaLYDiRPMBilZFU%2FrsK6FxRaU%2BlbjwePm0LW2duQF596FPd7IfktN1gUfvma2iGJ%2F5WzhKQQjilHVSD1HUdXE11Tv0NdN191JAaEWElRBvNcC6%2FWCeY%2FPUCk5sJ6HYdDSwjHGastI0p0julvuvhc19i1zFt0AND0FSq3VvXBIHonhaF%2Bu%2Bq4gcipyBn2YFQUcoSc%2B3m9zLNU9zYNCE5RJCRQb4DF9h2d0MGM%2B0Oj%2FOLlcim2ah1uN8nJBCRX%2BLth4pvIOkOx0OuPIB3e078A5mNe1JbejUYlPAh1uUiLkLiDkYExoxroriFmOCoTUDqMS8UbzFvJf4tMfWiXxgZA45QkBsZ5I3JqP6GHmqwwIlAML34%2BscGOqUBx9H%2BNu6jAsVJhrgc6KBJNpC%2FKbgEqK91wZf57z40srzdZTMeYHA6lYPzbtg89zMPFbveMHsOKrk3ZWDw5uuMin1RQ5fVJDroPph6oOEn6JRDCm3wDXmPnt5WfZqGAarifWhfL6f2tLn6%2FLyH%2FOkTfVz%2BAeTtwyea%2BiCrbvThmpnRLn2poIabnDCtrbdsmpj%2F0dFbS2PcHLLoyNJUjpQ9JOVQygNb&X-Amz-Signature=95a66a5b769f0a013bece886d3e27b2f6de6937b6f9a39758ded3db7b4258a14&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" alt="" class="gallery-image" loading="lazy" decoding="async" style="max-width:100%;height:auto;display:block;" onerror="this.style.display='none'">
            </div>
            
        </div>

        <div class="avaliacao">
            <div class="info-label mb-1">Avaliação</div>
            <div>Manejo de dessecação realizado, área apresenta alta pressão de daninhas. Realizaremos manejo sequencial para controle dessas pragas.</div>
        </div>
    </div>
</div>
    

</body>

</html>"""

# %%
import requests

response = requests.post(
    url="https://apdf.io/api/pdf/file/create",
    headers={
        "Content-Type": "application/json",
        "Authorization": "Bearer sBfdkCpJetRNsf6BP9lOMbePECWVH2rLn4sFOb2L839f590e",
    },
    json={"html": html},
)

response.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 14
#       1 import requests
#       3 response = requests.post(
#       4     url="https://apdf.io/api/pdf/file/create",
#       5     headers={
#    (...)     11     }
#      12 )
# ---> 14 response.raise_for_status()
#
# File c:\Users\Julia\git\notion-backend-vercel\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 504 Server Error: Gateway Time-out for url: https://apdf.io/api/pdf/file/create
